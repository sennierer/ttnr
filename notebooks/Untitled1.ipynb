# %%
Person.objects.all().count()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/django/db/backends/base/base.py in ensure_connection(self)
#     218             with self.wrap_database_errors:
# --> 219                 self.connect()
#     220
#
# ~/.local/lib/python3.8/site-packages/django/utils/asyncio.py in inner(*args, **kwargs)
#      25             # Pass onwards.
# ---> 26             return func(*args, **kwargs)
#      27         return inner
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/base/base.py in connect(self)
#     199         conn_params = self.get_connection_params()
# --> 200         self.connection = self.get_new_connection(conn_params)
#     201         self.set_autocommit(self.settings_dict['AUTOCOMMIT'])
#
# ~/.local/lib/python3.8/site-packages/django/utils/asyncio.py in inner(*args, **kwargs)
#      25             # Pass onwards.
# ---> 26             return func(*args, **kwargs)
#      27         return inner
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/postgresql/base.py in get_new_connection(self, conn_params)
#     186     def get_new_connection(self, conn_params):
# --> 187         connection = Database.connect(**conn_params)
#     188
#
# ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_9958/2761693333.py in <module>
# ----> 1 Person.objects.all().count()
#
# ~/.local/lib/python3.8/site-packages/django/db/models/query.py in count(self)
#     409             return len(self._result_cache)
#     410
# --> 411         return self.query.get_count(using=self.db)
#     412
#     413     def get(self, *args, **kwargs):
#
# ~/.local/lib/python3.8/site-packages/django/db/models/sql/query.py in get_count(self, using)
#     515         obj = self.clone()
#     516         obj.add_annotation(Count('*'), alias='__count', is_summary=True)
# --> 517         number = obj.get_aggregation(using, ['__count'])['__count']
#     518         if number is None:
#     519             number = 0
#
# ~/.local/lib/python3.8/site-packages/django/db/models/sql/query.py in get_aggregation(self, using, added_aggregate_names)
#     500         outer_query.select_related = False
#     501         compiler = outer_query.get_compiler(using)
# --> 502         result = compiler.execute_sql(SINGLE)
#     503         if result is None:
#     504             result = [None] * len(outer_query.annotation_select)
#
# ~/.local/lib/python3.8/site-packages/django/db/models/sql/compiler.py in execute_sql(self, result_type, chunked_fetch, chunk_size)
#    1152             cursor = self.connection.chunked_cursor()
#    1153         else:
# -> 1154             cursor = self.connection.cursor()
#    1155         try:
#    1156             cursor.execute(sql, params)
#
# ~/.local/lib/python3.8/site-packages/django/utils/asyncio.py in inner(*args, **kwargs)
#      24                         raise SynchronousOnlyOperation(message)
#      25             # Pass onwards.
# ---> 26             return func(*args, **kwargs)
#      27         return inner
#      28     # If the message is actually a function, then be a no-arguments decorator.
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/base/base.py in cursor(self)
#     257     def cursor(self):
#     258         """Create a cursor, opening a connection if necessary."""
# --> 259         return self._cursor()
#     260
#     261     @async_unsafe
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/base/base.py in _cursor(self, name)
#     233
#     234     def _cursor(self, name=None):
# --> 235         self.ensure_connection()
#     236         with self.wrap_database_errors:
#     237             return self._prepare_cursor(self.create_cursor(name))
#
# ~/.local/lib/python3.8/site-packages/django/utils/asyncio.py in inner(*args, **kwargs)
#      24                         raise SynchronousOnlyOperation(message)
#      25             # Pass onwards.
# ---> 26             return func(*args, **kwargs)
#      27         return inner
#      28     # If the message is actually a function, then be a no-arguments decorator.
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/base/base.py in ensure_connection(self)
#     217         if self.connection is None:
#     218             with self.wrap_database_errors:
# --> 219                 self.connect()
#     220
#     221     # ##### Backend-specific wrappers for PEP-249 connection methods #####
#
# ~/.local/lib/python3.8/site-packages/django/db/utils.py in __exit__(self, exc_type, exc_value, traceback)
#      88                 if dj_exc_type not in (DataError, IntegrityError):
#      89                     self.wrapper.errors_occurred = True
# ---> 90                 raise dj_exc_value.with_traceback(traceback) from exc_value
#      91
#      92     def __call__(self, func):
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/base/base.py in ensure_connection(self)
#     217         if self.connection is None:
#     218             with self.wrap_database_errors:
# --> 219                 self.connect()
#     220
#     221     # ##### Backend-specific wrappers for PEP-249 connection methods #####
#
# ~/.local/lib/python3.8/site-packages/django/utils/asyncio.py in inner(*args, **kwargs)
#      24                         raise SynchronousOnlyOperation(message)
#      25             # Pass onwards.
# ---> 26             return func(*args, **kwargs)
#      27         return inner
#      28     # If the message is actually a function, then be a no-arguments decorator.
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/base/base.py in connect(self)
#     198         # Establish the connection
#     199         conn_params = self.get_connection_params()
# --> 200         self.connection = self.get_new_connection(conn_params)
#     201         self.set_autocommit(self.settings_dict['AUTOCOMMIT'])
#     202         self.init_connection_state()
#
# ~/.local/lib/python3.8/site-packages/django/utils/asyncio.py in inner(*args, **kwargs)
#      24                         raise SynchronousOnlyOperation(message)
#      25             # Pass onwards.
# ---> 26             return func(*args, **kwargs)
#      27         return inner
#      28     # If the message is actually a function, then be a no-arguments decorator.
#
# ~/.local/lib/python3.8/site-packages/django/db/backends/postgresql/base.py in get_new_connection(self, conn_params)
#     185     @async_unsafe
#     186     def get_new_connection(self, conn_params):
# --> 187         connection = Database.connect(**conn_params)
#     188
#     189         # self.isolation_level must be set:
#
# ~/.local/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: server closed the connection unexpectedly
# 	This probably means the server terminated abnormally
# 	before or while processing the request.

# %%
import os
import django
os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'rest.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"
django.setup()

# %%
P
